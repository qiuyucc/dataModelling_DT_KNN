# %%
#Data preparation:To load the data from csv file based on its format
student_p = 'student-por.csv'
student_m = 'student-mat.csv'
import pandas as pd
por = pd.read_csv(student_p, sep =';')
mat = pd.read_csv(student_m, sep=';')
df=pd.concat([mat,por])
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other ...
# 3     GP   F   15       U     GT3       T     4     2   health  services ...
# 4     GP   F   16       U     GT3       T     3     3    other     other ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.columns
# Out:
# Index([u'school', u'sex', u'age', u'address', u'famsize', u'Pstatus', u'Medu',
#        u'Fedu', u'Mjob', u'Fjob', u'reason', u'guardian', u'traveltime',
#        u'studytime', u'failures', u'schoolsup', u'famsup', u'paid',
#        u'activities', u'nursery', u'higher', u'internet', u'romantic',
#        u'famrel', u'freetime', u'goout', u'Dalc', u'Walc', u'health',
#        u'absences', u'G1', u'G2', u'G3'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1044 entries, 0 to 648
# Data columns (total 33 columns):
# school        1044 non-null object
# sex           1044 non-null object
# age           1044 non-null int64
# address       1044 non-null object
# famsize       1044 non-null object
# Pstatus       1044 non-null object
# Medu          1044 non-null int64
# Fedu          1044 non-null int64
# Mjob          1044 non-null object
# Fjob          1044 non-null object
# reason        1044 non-null object
# guardian      1044 non-null object
# traveltime    1044 non-null int64
# studytime     1044 non-null int64
# failures      1044 non-null int64
# schoolsup     1044 non-null object
# famsup        1044 non-null object
# paid          1044 non-null object
# activities    1044 non-null object
# nursery       1044 non-null object
# higher        1044 non-null object
# internet      1044 non-null object
# romantic      1044 non-null object
# famrel        1044 non-null int64
# ...

# %%
df['school'].value_counts()
# Out:
# GP    772
# MS    272
# Name: school, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# F    591
# M    453
# Name: sex, dtype: int64

# %%
df['age'].value_counts()
# Out:
# 16    281
# 17    277
# 18    222
# 15    194
# 19     56
# 20      9
# 21      3
# 22      2
# Name: age, dtype: int64

# %%
df['address'].value_counts()
# Out:
# U    759
# R    285
# Name: address, dtype: int64

# %%
df['famsize'].value_counts()
# Out:
# GT3    738
# LE3    306
# Name: famsize, dtype: int64

# %%
df['Pstatus'].value_counts()
# Out:
# T    923
# A    121
# Name: Pstatus, dtype: int64

# %%
df['Medu'].value_counts()
# Out:
# 4    306
# 2    289
# 3    238
# 1    202
# 0      9
# Name: Medu, dtype: int64

# %%
df['Fedu'].value_counts()
# Out:
# 2    324
# 1    256
# 3    231
# 4    224
# 0      9
# Name: Fedu, dtype: int64

# %%
df['Mjob'].value_counts()
# Out:
# other       399
# services    239
# at_home     194
# teacher     130
# health       82
# Name: Mjob, dtype: int64

# %%
df['Fjob'].value_counts()
# Out:
# other       584
# services    292
# teacher      65
# at_home      62
# health       41
# Name: Fjob, dtype: int64

# %%
df['reason'].value_counts()
# Out:
# course        430
# home          258
# reputation    248
# other         108
# Name: reason, dtype: int64

# %%
df['guardian'].value_counts()
# Out:
# mother    728
# father    243
# other      73
# Name: guardian, dtype: int64

# %%
df['traveltime'].value_counts()
# Out:
# 1    623
# 2    320
# 3     77
# 4     24
# Name: traveltime, dtype: int64

# %%
df['studytime'].value_counts()
# Out:
# 2    503
# 1    317
# 3    162
# 4     62
# Name: studytime, dtype: int64

# %%
df['failures'].value_counts()
# Out:
# 0    861
# 1    120
# 2     33
# 3     30
# Name: failures, dtype: int64

# %%
df['schoolsup'].value_counts()
# Out:
# no     925
# yes    119
# Name: schoolsup, dtype: int64

# %%
df['famsup'].value_counts()
# Out:
# yes    640
# no     404
# Name: famsup, dtype: int64

# %%
df['paid'].value_counts()
# Out:
# no     824
# yes    220
# Name: paid, dtype: int64

# %%
df['activities'].value_counts()
# Out:
# no     528
# yes    516
# Name: activities, dtype: int64

# %%
df['nursery'].value_counts()
# Out:
# yes    835
# no     209
# Name: nursery, dtype: int64

# %%
df['higher'].value_counts()
# Out:
# yes    955
# no      89
# Name: higher, dtype: int64

# %%
df['internet'].value_counts()
# Out:
# yes    827
# no     217
# Name: internet, dtype: int64

# %%
df['romantic'].value_counts()
# Out:
# no     673
# yes    371
# Name: romantic, dtype: int64

# %%
df['famrel'].value_counts()
# Out:
# 4    512
# 5    286
# 3    169
# 2     47
# 1     30
# Name: famrel, dtype: int64

# %%
df['freetime'].value_counts()
# Out:
# 3    408
# 4    293
# 2    171
# 5    108
# 1     64
# Name: freetime, dtype: int64

# %%
df['goout'].value_counts()
# Out:
# 3    335
# 2    248
# 4    227
# 5    163
# 1     71
# Name: goout, dtype: int64

# %%
df['Dalc'].value_counts()
# Out:
# 1    727
# 2    196
# 3     69
# 5     26
# 4     26
# Name: Dalc, dtype: int64

# %%
df['Walc'].value_counts()
# Out:
# 1    398
# 2    235
# 3    200
# 4    138
# 5     73
# Name: Walc, dtype: int64

# %%
df['health'].value_counts()
# Out:
# 5    395
# 3    215
# 4    174
# 1    137
# 2    123
# Name: health, dtype: int64

# %%
df['absences'].value_counts()
# Out:
# 0     359
# 2     175
# 4     146
# 6      80
# 8      64
# 10     38
# 12     24
# 14     20
# 5      17
# 16     17
# 1      15
# 3      15
# 7      10
# 9      10
# 18      8
# 11      8
# 15      5
# 22      5
# 20      4
# 13      4
# 21      3
# 24      2
# 26      2
# 30      2
# 75      1
# 56      1
# 19      1
# 23      1
# 25      1
# 28      1
# 32      1
# 38      1
# 40      1
# 54      1
# 17      1
# Name: absences, dtype: int64

# %%
df['G1'].value_counts()
# Out:
# 10    146
# 11    130
# 12    117
# 13    105
# 14    101
# 9      96
# 8      83
# 7      70
# 15     59
# 16     44
# 6      33
# 17     24
# 18     15
# 5      12
# 19      4
# 4       3
# 3       1
# 0       1
# Name: G1, dtype: int64

# %%
df['G2'].value_counts()
# Out:
# 11    138
# 10    129
# 12    127
# 9     122
# 13    117
# 14     77
# 15     72
# 8      72
# 16     38
# 7      37
# 18     26
# 17     25
# 6      21
# 0      20
# 5      18
# 19      4
# 4       1
# Name: G2, dtype: int64

# %%
df['G3'].value_counts()
# Out:
# 10    153
# 11    151
# 13    113
# 12    103
# 14     90
# 15     82
# 8      67
# 9      63
# 0      53
# 16     52
# 17     35
# 18     27
# 7      19
# 6      18
# 5       8
# 19      7
# 4       1
# 1       1
# 20      1
# Name: G3, dtype: int64

# %%
df.drop_duplicates()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %%
df.isnull().sum(axis=0)
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
#convert final grade which is G3 to categorical: Distinction, pass and fail
df['Grade'] = 'NaN'
df.loc[(df.G3 >= 15) & (df.G3 <= 20), 'Grade'] = 'Distinction' 
df.loc[(df.G3 >= 10) & (df.G3 <= 14), 'Grade'] = 'Pass' 
df.loc[(df.G3 >= 0) & (df.G3 <= 9), 'Grade'] = 'Fail' 
df.head(5)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#       ...      freetime goout  Dalc  Walc  health absences  G1  G2  G3  \
# 0     ...             3     4     1     1       3        6   5   6   6
# 1     ...             3     3     1     1       3        4   5   5   6
# 2     ...             3     2     2     3       3       10   7   8  10
# 3     ...             2     2     1     1       5        2  15  14  15
# 4     ...             3     2     1     2       5        4   6  10  10
#
#          Grade
# 0         Fail
# 1         Fail
# 2         Pass
# 3  Distinction
# 4         Pass
# ...

# %%
df.describe()
# Out:
#                age         Medu         Fedu   traveltime    studytime  \
# count  1044.000000  1044.000000  1044.000000  1044.000000  1044.000000
# mean     16.726054     2.603448     2.387931     1.522989     1.970307
# std       1.239975     1.124907     1.099938     0.731727     0.834353
# min      15.000000     0.000000     0.000000     1.000000     1.000000
# 25%      16.000000     2.000000     1.000000     1.000000     1.000000
# 50%      17.000000     3.000000     2.000000     1.000000     2.000000
# 75%      18.000000     4.000000     3.000000     2.000000     2.000000
# max      22.000000     4.000000     4.000000     4.000000     4.000000
#
#           failures       famrel     freetime        goout         Dalc  \
# count  1044.000000  1044.000000  1044.000000  1044.000000  1044.000000
# mean      0.264368     3.935824     3.201149     3.156130     1.494253
# std       0.656142     0.933401     1.031507     1.152575     0.911714
# ...

# %%
#Data exploration: explore each column
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
explode=(0,0.1)
df['school'].value_counts().plot(kind='pie',autopct='%.2f',figsize=(4,4),explode=explode)
plt.title('School Proportion')
plt.xlabel ('GP-Gabriel Pereira MS-Mousinho da Silverira')
plt.show()
#This table shows sample for this data set, 65.18% student from GP, 34.82% student from MS

# %%
df['sex'].value_counts().plot(kind='pie',autopct='%.2f',figsize=(4,4),colors =['sandybrown','chocolate'],explode = explode)
plt.title('Gender Proportion')
plt.xlabel ('F-Female M-Male')
plt.show()
#This table shows sample for this data set, 40.99% students are male, 59.01% students from female

# %%
d_age={'age': df.age}
d_age=d_age['age'].value_counts().reset_index()
d_age.columns = ['age','count']
d_a=pd.DataFrame(d_age)
d_a.plot(kind='bar',x='age',y='count')
plt.title('Student Age distribution')
plt.ylabel('number')
plt.show()
# The table shows the sample for this data set, the student age distribution

# %%
df['address'].value_counts().plot(kind='pie',autopct='%.2f',figsize=(4,4),explode =explode)
plt.title('Address Proportion')
plt.xlabel ('U - urban R - rural')
plt.show()
#The table shows the proportion of student lives, 69.65% from urban area, 30.35% from rural areas

# %%
df['Pstatus'].value_counts().plot(kind='pie',autopct='%.2f',figsize=(4,4),explode =explode)
plt.title('Parent conhabitaton status Proportion')
plt.xlabel ('T - together A - apart')
plt.show()

#The table shows the proporttion of parent conhabitation status proportion, 87.67% livig together, 12.33% live apart.

# %%
df['health'].plot(kind = 'density')
plt.title('Student health density')
plt.xlabel('health rate\nfrom 1 - very bad to 5 - very good')
plt.xlim(0,5)
plt.show()
#The table shows the density of health rate for students

# %%
d_freetime={'freetime': df.freetime}
d_freetime=d_freetime['freetime'].value_counts().reset_index()
d_freetime.columns = ['freetime','count']
d_temp=pd.DataFrame(d_freetime)
d_temp.plot(kind='bar',x='freetime',y='count')
plt.title('Student freetime distribution')
plt.ylabel('number of students')
plt.xlabel('\nfrom 1 - very low to 5 - very high')
plt.show()

# %%
df['romantic'].value_counts().plot(kind='pie',autopct='%.2f',figsize=(4,4),explode =explode)
plt.title('Student in relationship Proportion')
plt.show()
#The table shows student who has relationship

# %%
df['absences'].plot(kind = 'density')
plt.title('School absences density')
plt.xlabel('number of absences')
plt.xlim(0,35)
plt.show()
#The table shows the density of health rate for students

# %%
d_studytime={'studytime': df.studytime}
d_studytime=d_studytime['studytime'].value_counts().reset_index()
d_studytime.columns = ['studytime','count']
d_temp=pd.DataFrame(d_studytime)
d_temp.plot(kind='bar',x='studytime',y='count')
plt.title('Student studytime distribution')
plt.ylabel('number of students')
plt.xlabel('\n1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours')
plt.show()
#the table shows the student studytime distribution

# %%
#the table shows the final grade distribution for student
plt.hist(df['G3'],bins=17, normed =True, alpha=0.5, histtype='stepfilled',color='steelblue',edgecolor ='black')
plt.title('final grade distribution')
plt.xlabel('grade')
plt.ylabel('density')
plt.show()
# Out:
# D:\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
#overall correlation heatmap
corr = df.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr,annot =True, cmap="Reds")
plt.title('Correlation Heatmap',fontsize=20)
# Out:
# Text(0.5,1,'Correlation Heatmap')

# %%
num_gp=df['school'].value_counts().GP
num_gp=df['school'].value_counts().MS

# %%
# relationship in pairs
# School vs final grade
# comparsion of final grade between differents school
perc = (lambda col: col/col.sum())
index = ['Fail','Pass','Distinction']
school_tab = pd.crosstab(df.Grade,df.school)
school_perc = school_tab.apply(perc).reindex(index)
print school_perc
# Out:
# school             GP        MS
# Grade
# Fail         0.187824  0.312500
# Pass         0.595855  0.551471
# Distinction  0.216321  0.136029

# %%
plt.figure()
school_perc.plot.bar(fontsize=12, figsize=(6,6))
plt.title('Grade By School', fontsize=16)
plt.ylabel('Percentage of Logarithm Student Counts ', fontsize=12)
plt.xlabel('Grade', fontsize=12)
plt.show()
#GP school may have better education quality than MS

# %%
#student with a romantic relationship vs grade
perc = (lambda col: col/col.sum())
romantic_tab = pd.crosstab(df.Grade,df.romantic)
romantic_perc = romantic_tab.apply(perc).reindex(index)
print romantic_perc
# Out:
# romantic           no       yes
# Grade
# Fail         0.196137  0.264151
# Pass         0.600297  0.555256
# Distinction  0.203566  0.180593

# %%
plt.figure()
romantic_perc.plot.bar(fontsize=12, figsize=(6,6),colormap='RdBu')
plt.title('Final Grade By romantic relationship', fontsize=16)
plt.ylabel('Percentage of Logarithm Student Counts ', fontsize=12)
plt.xlabel('Final Grade', fontsize=12)
plt.show()
#having relationship will affect grade in final

# %%
#Traveltime vs grades
perc = (lambda col: col/col.sum())
traveltime_tab = pd.crosstab(df.Grade,df.traveltime)
traveltime_perc = traveltime_tab.apply(perc).reindex(index)
print traveltime_perc
# Out:
# traveltime          1         2        3         4
# Grade
# Fail         0.210273  0.228125  0.25974  0.250000
# Pass         0.573034  0.590625  0.61039  0.708333
# Distinction  0.216693  0.181250  0.12987  0.041667

# %%
plt.figure()
traveltime_perc.plot.bar(fontsize=12, figsize=(6,6),colormap='RdBu')
plt.title('Grade By travel time', fontsize=16)
plt.ylabel('Percentage of Logarithm Student Counts ', fontsize=12)
plt.xlabel('Grade\n 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour', fontsize=12)
plt.show()
#The result shows that, the more time student spends on traveling from school to home have a significant impact study

# %%
#student study hour vs grade
studytime_tab1 = pd.crosstab(index=df.Grade, columns=df.studytime)
studytime_tab= np.log(studytime_tab1)
studytime_perc = studytime_tab.apply(perc).reindex(index)
print studytime_perc
# Out:
# studytime           1         2         3         4
# Grade
# Fail         0.333232  0.314428  0.272010  0.255077
# Pass         0.391516  0.379460  0.390367  0.416013
# Distinction  0.275252  0.306112  0.337623  0.328910

# %%
#create dataframe for different grade categories
fail=df.loc[df.Grade =='Fail']
fail['fail'] = fail.studytime
Pass=df.loc[df.Grade =='Pass']
Pass['pass'] = Pass.studytime
distinction=df.loc[df.Grade =='Distinction']
distinction['distinction'] = distinction.studytime
plt.figure(figsize=(10,6))
graph=sns.kdeplot(fail['fail'],shade=True,color='g')
graph=sns.kdeplot(Pass['pass'] ,shade=True,color='b')
graph=sns.kdeplot(distinction['distinction'],shade=True,color='r')
plt.title('Grade by studytime')
plt.ylabel('Density',fontsize=12)
plt.xlabel('studytime \n1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours',fontsize=12)
#we can tell from graph, more time on study, the grade higher
# Out:
# D:\Anaconda2\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# D:\Anaconda2\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# D:\Anaconda2\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#schoolsup vs grade
#Does extral educational support affect grade
schoolsup_tab = pd.crosstab(index=df.Grade, columns=df.schoolsup)
schoolsup_perc = schoolsup_tab.apply(perc).reindex(index)
print schoolsup_perc
# Out:
# schoolsup          no       yes
# Grade
# Fail         0.215135  0.260504
# Pass         0.568649  0.705882
# Distinction  0.216216  0.033613

# %%
plt.figure()
schoolsup_perc.plot.bar(fontsize=12, figsize=(6,6),colormap='OrRd')
plt.title('Grade By extral educational support', fontsize=16)
plt.ylabel('Percentage of Logarithm Student Counts ', fontsize=12)
plt.xlabel('Grade\n', fontsize=12)
plt.show()
#extral educational support don't have much impacts on student's grade.
#for achieving distinction, student may need put more efforts by themselves.

# %%
#quality of family relationship vs grade
fail=df.loc[df.Grade =='Fail']
fail['fail_famrel'] = fail.famrel
Pass=df.loc[df.Grade =='Pass']
Pass['pass_famrel'] = Pass.famrel
distinction=df.loc[df.Grade =='Distinction']
distinction['distinction_famrel'] = distinction.famrel
plt.figure(figsize=(10,6))
graph=sns.kdeplot(fail['fail_famrel'],shade=True,color='g')
graph=sns.kdeplot(Pass['pass_famrel'] ,shade=True,color='b')
graph=sns.kdeplot(distinction['distinction_famrel'],shade=True,color='r')
plt.title('Grade by quality of family')
plt.ylabel('Density',fontsize=12)
plt.xlabel('Quality of family \nfrom 1 - very bad to 5 - excellent',fontsize=12)
#The quality of family relationship have impacts on student's grade
#bad quality of family relationship may not provide good environment for student
#However, the excellent family relationship cannot ensure the good result
# Out:
# D:\Anaconda2\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# D:\Anaconda2\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# D:\Anaconda2\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#mother's education level vs child's grade
fail=df.loc[df.Grade =='Fail']
fail['fail_mother_education'] = fail.Medu
Pass=df.loc[df.Grade =='Pass']
Pass['pass_mother_education'] = Pass.Medu
distinction=df.loc[df.Grade =='Distinction']
distinction['distinction_mother_education'] = distinction.Medu
plt.figure(figsize=(10,6))
graph=sns.kdeplot(fail['fail_mother_education'],shade=True,color='g')
graph=sns.kdeplot(Pass['pass_mother_education'] ,shade=True,color='b')
graph=sns.kdeplot(distinction['distinction_mother_education'],shade=True,color='r')
plt.title('Grade by mother education level')
plt.ylabel('Density',fontsize=12)
plt.xlabel('mother education level \n0 - none, 1 - primary education (4th grade), 2 - 5th to 9th grade, 3 - secondary education or 4 - higher education',fontsize=12)
#mother's education level has impacts on student's grade
# Out:
# D:\Anaconda2\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# D:\Anaconda2\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# D:\Anaconda2\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#father's education level vs child's grade
fail=df.loc[df.Grade =='Fail']
fail['fail_father_education'] = fail.Fedu
Pass=df.loc[df.Grade =='Pass']
Pass['pass_father_education'] = Pass.Fedu
distinction=df.loc[df.Grade =='Distinction']
distinction['distinction_father_education'] = distinction.Fedu
plt.figure(figsize=(10,6))
graph=sns.kdeplot(fail['fail_father_education'],shade=True,color='g')
graph=sns.kdeplot(Pass['pass_father_education'] ,shade=True,color='b')
graph=sns.kdeplot(distinction['distinction_father_education'],shade=True,color='r')
plt.title('Grade by father education level')
plt.ylabel('Density',fontsize=12)
plt.xlabel('father education level \n0 - none, 1 - primary education (4th grade), 2 - 5th to 9th grade, 3 - secondary education or 4 - higher education',fontsize=12)
#father's education level doesn't give much impacts on child's grade, probably get married with someone with higher education is good option
# Out:
# D:\Anaconda2\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# D:\Anaconda2\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# D:\Anaconda2\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
health_tab = pd.crosstab(index=df.Grade, columns=df.health)
health_perc = health_tab.apply(perc).reindex(index)
print health_perc
# Out:
# health              1         2         3         4         5
# Grade
# Fail         0.197080  0.195122  0.227907  0.206897  0.237975
# Pass         0.481752  0.585366  0.632558  0.597701  0.587342
# Distinction  0.321168  0.219512  0.139535  0.195402  0.174684

# %%
#health vs grade
plt.figure(figsize=(6,8))
sns.boxplot(x='health', y='G3',data=df)
plt.title('Grade by health level')
plt.ylabel('Density',fontsize=12)
plt.xlabel('health level \n1 - very bad to 5 - very good',fontsize=12)
#surprisingly, students who has bad health level has better grades slightly
# Out:
# Text(0.5,0,'health level \n1 - very bad to 5 - very good')

# %%
#higher education & grade
higher_tab = pd.crosstab(index=df.Grade, columns=df.higher)
higher_perc = higher_tab.apply(perc).reindex(index)
print higher_perc
# Out:
# higher             no       yes
# Grade
# Fail         0.516854  0.192670
# Pass         0.483146  0.593717
# Distinction  0.000000  0.213613

# %%
plt.figure()
higher_perc.plot.bar(fontsize=12, figsize=(6,6),colormap='GnBu')
plt.title('Grade By higher education plan', fontsize=16)
plt.ylabel('Percentage of Logarithm Student Counts ', fontsize=12)
plt.xlabel('Grade\n', fontsize=12)
plt.show()
#it's easy to tell that student who has intention for futher student will have better grade

# %%
#Data Modelling -classification
#K-nearest neighbour
#Predict student's G3(final grade) by using students information
dfm = df.copy()
dfm = dfm.drop(['G3'],axis=1)

# %%
dfm.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#       ...      famrel freetime  goout  Dalc  Walc health absences  G1  G2  \
# 0     ...           4        3      4     1     1      3        6   5   6
# 1     ...           5        3      3     1     1      3        4   5   5
# 2     ...           4        3      2     2     3      3       10   7   8
# 3     ...           3        2      2     1     1      5        2  15  14
# 4     ...           4        3      2     1     2      5        4   6  10
#
#          Grade
# 0         Fail
# 1         Fail
# 2         Pass
# ...

# %%
#standardize the variables
#label encode grade
#0-Distinction, 2-Pass,  3-Fail
from sklearn import preprocessing
label = preprocessing.LabelEncoder()
dfm.Grade = label.fit_transform(dfm.Grade)
dfm.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#    ...  famrel freetime  goout  Dalc  Walc health absences  G1  G2 Grade
# 0  ...       4        3      4     1     1      3        6   5   6     1
# 1  ...       5        3      3     1     1      3        4   5   5     1
# 2  ...       4        3      2     2     3      3       10   7   8     2
# 3  ...       3        2      2     1     1      5        2  15  14     0
# 4  ...       4        3      2     1     2      5        4   6  10     2
#
# [5 rows x 33 columns]

# %%
#train dataset & test dataset split #data prepartion 20% test dat
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
X=dfm.drop('Grade',axis=1)
y=dfm.Grade
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)
#get dummy varibles
X_train = pd.get_dummies(X_train)
X_test = pd.get_dummies(X_test)
#check how many features in this dataset
len(list(X_train))
# Out:
# 58

# %%
#choosing a k -value   !elbow method
# create a for loop that trains various KNN models with different K values
# then keep track of the error rate for each of these models.
import numpy as np
error_rate = []
for i in range(1,30):
    knn = KNeighborsClassifier(n_neighbors = i)
    knn.fit(X_train, y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))
plt.figure(figsize=(15,6))
plt.plot(range(1,30),error_rate,color='red',linestyle='dashed',marker='o', markerfacecolor='blue', markersize='10')
plt.title("Error rate by K-value while 0.2 test size")
plt.xlabel('no. of K')
plt.ylabel('Error Rate')
# Out:
# Text(0,0.5,'Error Rate')

# %%
#retrain with new k value, we can tell the best K value is 6 which has the least error rate
from sklearn.metrics import classification_report
clf = KNeighborsClassifier(n_neighbors =11)
fit =clf.fit(X_train, y_train)
y_pred = fit.predict(X_test)
cm =confusion_matrix(y_test, y_pred)
ts =fit.score(X_test,y_test)
print("Decisioin Tree Model Score" , ":" , fit.score(X_train, y_train) , "," , 
      "Cross Validation Score" ,":" , fit.score(X_test, y_test))
print ts
print cm
print(classification_report(y_test, y_pred))
# Out:
# ('Decisioin Tree Model Score', ':', 0.8735632183908046, ',', 'Cross Validation Score', ':', 0.8275862068965517)
# 0.8275862068965517
# [[ 78   0  25]
#  [  0  77  50]
#  [  5  10 277]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.76      0.84       103
#            1       0.89      0.61      0.72       127
#            2       0.79      0.95      0.86       292
#
#    micro avg       0.83      0.83      0.83       522
#    macro avg       0.87      0.77      0.81       522
# weighted avg       0.84      0.83      0.82       522

# %%
#decision tree test size =0.2
#find minimum samples leaf
from sklearn.tree import DecisionTreeClassifier 
msl=[]
for i in range(1,58):
    tree = DecisionTreeClassifier(min_samples_leaf=i)
    t= tree.fit(X_train, y_train)
    ts=t.score(X_test, y_test)
    msl.append(ts)
msl = pd.Series(msl)
msl.where(msl==msl.max()).dropna()
# Out:
# 13    0.866029
# 19    0.866029
# dtype: float64

# %%
# final model
import pydotplus
from sklearn.externals.six import StringIO 
from IPython.display import Image  
from sklearn.tree import export_graphviz
tree = DecisionTreeClassifier(min_samples_leaf=19)
t= tree.fit(X_train, y_train)
y_pred = t.predict(X_test)
cm =confusion_matrix(y_test, y_pred)
ts =t.score(X_test,y_test)
print ts
print cm
print(classification_report(y_test, y_pred))
print("Decisioin Tree Model Score" , ":" , t.score(X_train, y_train) , "," , 
      "Cross Validation Score" ,":" , t.score(X_test, y_test))
dot_data = StringIO()
export_graphviz(t,out_file=dot_data,filled=True, rounded =True,
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('DesicionTree20%.png')
Image(graph.create_png())
# Out:
# 0.8582375478927203
# [[ 91   0  12]
#  [  0 104  23]
#  [  9  30 253]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.88      0.90       103
#            1       0.78      0.82      0.80       127
#            2       0.88      0.87      0.87       292
#
#    micro avg       0.86      0.86      0.86       522
#    macro avg       0.85      0.86      0.86       522
# weighted avg       0.86      0.86      0.86       522
#
# ('Decisioin Tree Model Score', ':', 0.8831417624521073, ',', 'Cross Validation Score', ':', 0.8582375478927203)

# %%
#test size =0.4
X=dfm.drop('Grade',axis=1)
y=dfm.Grade
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4)
#get dummy varibles
X_train = pd.get_dummies(X_train)
X_test = pd.get_dummies(X_test)

# %%
#KNN test size =0.4
error_rate = []
for i in range(1,30):
    knn = KNeighborsClassifier(n_neighbors = i)
    knn.fit(X_train, y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))
plt.figure(figsize=(15,6))
plt.plot(range(1,30),error_rate,color='red',linestyle='dashed',marker='o', markerfacecolor='blue', markersize='10')
plt.title("Error rate by K-value while 0.4 test size")
plt.xlabel('no. of K')
plt.ylabel('Error Rate')
# Out:
# Text(0,0.5,'Error Rate')

# %%
clf = KNeighborsClassifier(n_neighbors =13)
fit =clf.fit(X_train, y_train)
y_pred = fit.predict(X_test)
cm =confusion_matrix(y_test, y_pred)
ts =fit.score(X_test,y_test)
print ts
print cm
print(classification_report(y_test, y_pred))
print("Decisioin Tree Model Score" , ":" , fit.score(X_train, y_train) , "," , 
      "Cross Validation Score" ,":" , fit.score(X_test, y_test))
# Out:
# 0.8237547892720306
# [[ 77   0  26]
#  [  0  76  51]
#  [  8   7 277]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.75      0.82       103
#            1       0.92      0.60      0.72       127
#            2       0.78      0.95      0.86       292
#
#    micro avg       0.82      0.82      0.82       522
#    macro avg       0.87      0.76      0.80       522
# weighted avg       0.84      0.82      0.82       522
#
# ('Decisioin Tree Model Score', ':', 0.8659003831417624, ',', 'Cross Validation Score', ':', 0.8237547892720306)

# %%
#decision tree test size =0.4
#find minimum samples leaf
from sklearn.tree import DecisionTreeClassifier 
msl=[]
for i in range(1,58):
    tree = DecisionTreeClassifier(min_samples_leaf=i)
    t= tree.fit(X_train, y_train)
    ts=t.score(X_test, y_test)
    msl.append(ts)
msl = pd.Series(msl)
msl.where(msl==msl.max()).dropna()
# Out:
# 12    0.873206
# 13    0.873206
# dtype: float64

# %%
# final model
tree = DecisionTreeClassifier(min_samples_leaf=13)
t= tree.fit(X_train, y_train)
y_pred = t.predict(X_test)
cm =confusion_matrix(y_test, y_pred)
ts =t.score(X_test,y_test)
print ts
print cm
print(classification_report(y_test, y_pred))
print("Decisioin Tree Model Score" , ":" , t.score(X_train, y_train) , "," , 
      "Cross Validation Score" ,":" , t.score(X_test, y_test))

dot_data = StringIO()
export_graphviz(t,out_file=dot_data,filled=True, rounded =True,
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('DesicionTree40%.png')
Image(graph.create_png())
# Out:
# 0.8888888888888888
# [[ 95   0   8]
#  [  0 106  21]
#  [ 11  18 263]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91       103
#            1       0.85      0.83      0.84       127
#            2       0.90      0.90      0.90       292
#
#    micro avg       0.89      0.89      0.89       522
#    macro avg       0.88      0.89      0.88       522
# weighted avg       0.89      0.89      0.89       522
#
# ('Decisioin Tree Model Score', ':', 0.896551724137931, ',', 'Cross Validation Score', ':', 0.8888888888888888)

# %%
#test size =0.5
X=dfm.drop('Grade',axis=1)
y=dfm.Grade
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.5)
#get dummy varibles
X_train = pd.get_dummies(X_train)
X_test = pd.get_dummies(X_test)

# %%
error_rate = []
for i in range(1,30):
    knn = KNeighborsClassifier(n_neighbors = i)
    knn.fit(X_train, y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))
plt.figure(figsize=(15,6))
plt.plot(range(1,30),error_rate,color='red',linestyle='dashed',marker='o', markerfacecolor='blue', markersize='10')
plt.title("Error rate by K-value while 0.5 test size")
plt.xlabel('no. of K')
plt.ylabel('Error Rate')
# Out:
# Text(0,0.5,'Error Rate')

# %%
clf = KNeighborsClassifier(n_neighbors = 11)
fit =clf.fit(X_train, y_train)
y_pred = fit.predict(X_test)
cm =confusion_matrix(y_test, y_pred)
ts =fit.score(X_test,y_test)
print ts
print cm
print(classification_report(y_test, y_pred))
print("Decisioin Tree Model Score" , ":" , fit.score(X_train, y_train) , "," , 
      "Cross Validation Score" ,":" , fit.score(X_test, y_test))
# Out:
# 0.8275862068965517
# [[ 78   0  25]
#  [  0  77  50]
#  [  5  10 277]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.76      0.84       103
#            1       0.89      0.61      0.72       127
#            2       0.79      0.95      0.86       292
#
#    micro avg       0.83      0.83      0.83       522
#    macro avg       0.87      0.77      0.81       522
# weighted avg       0.84      0.83      0.82       522
#
# ('Decisioin Tree Model Score', ':', 0.8735632183908046, ',', 'Cross Validation Score', ':', 0.8275862068965517)

# %%
#decision tree test size =0.5
#find minimum samples leaf
from sklearn.tree import DecisionTreeClassifier 
msl=[]
for i in range(1,58):
    tree = DecisionTreeClassifier(min_samples_leaf=i)
    t= tree.fit(X_train, y_train)
    ts=t.score(X_test, y_test)
    msl.append(ts)
msl = pd.Series(msl)
msl.where(msl==msl.max()).dropna()
# Out:
# 11    0.888889
# 12    0.888889
# dtype: float64

# %%
# final model
tree = DecisionTreeClassifier(min_samples_leaf=11)
t= tree.fit(X_train, y_train)
y_pred = t.predict(X_test)
cm =confusion_matrix(y_test, y_pred)
ts =t.score(X_test,y_test)
print ts
print cm
print(classification_report(y_test, y_pred))
print("Decisioin Tree Model Score" , ":" , t.score(X_train, y_train) , "," , 
      "Cross Validation Score" ,":" , t.score(X_test, y_test))

dot_data = StringIO()
export_graphviz(t,out_file=dot_data,filled=True, rounded =True,
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('DesicionTree50%.png')
Image(graph.create_png())
# Out:
# 0.8831417624521073
# [[ 95   0   8]
#  [  0 106  21]
#  [ 11  21 260]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91       103
#            1       0.83      0.83      0.83       127
#            2       0.90      0.89      0.90       292
#
#    micro avg       0.88      0.88      0.88       522
#    macro avg       0.88      0.88      0.88       522
# weighted avg       0.88      0.88      0.88       522
#
# ('Decisioin Tree Model Score', ':', 0.9022988505747126, ',', 'Cross Validation Score', ':', 0.8831417624521073)
